# %% [markdown]
# **PRAKTIKUM**

# %% [markdown]
# 1. buka google colab dan import gambar

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/sample_data/kucing.jpg')
plt.imshow(img)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi cvhannel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/sample_data/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/file image', img5)

#tampilkan plot dengan canvas ynag lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=100)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 cahnnel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 5. Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih File kemudian “Save a copy in GitHub”.

# %% [markdown]
# **PERTANYAAN**

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# > jawab : Gambar yang ditampilkan menggunakan matplotlib pada setiap sumbu memiliki sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna yang interaktif.

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# > jawab : Penggunaan int16 memiliki rentang jarak dtype antara 32768-32767 untuk black image dengan tingkat keabuan yang lebih rendah karena memiliki kisaran nilai yang lebih sempit. Ini berarti perbedaan antara warna hitam dan putih mungkin akan lebih halus dan lebih sulit dibedakan pada gambar.
# int32 memiliki kisaran nilai -231-231, sehingga dapat digunakan untuk black image dengan tingkat keabuan yang lebih tinggi.

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut!
#
# > from google.colab.patches import cv2_imshow
# >
# > from skimage import io
# >
# > jawab :  from google.colab.patches import cv2_imshow digunakan untuk memungkinkan tampilan gambar hasil pemrosesan dalam google Colab dengan bantuan OpenCV (cv2).

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3!
#
# > jawab : from skimage import io mungkin akan digunakan untuk membaca atau memproses gambar yang akan ditampilkan. Melakukan import library io dari source skimage. library ini memiliki fungsi untuk mengkonversi gambar ndarray, seperti rgb2gray

# %% [markdown]
# **TUGAS INDIVIDU**

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
#
# > Tidak, penggunaan figsize dalam Matplotlib hanya mengubah ukuran gambar yang akan ditampilkan, bukan ukuran pixel dalam gambar itu sendiri.

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
# Membaca gambar
#imgx = cv2.imread('/content/sample_data/kucing.jpg')  #

img_rb = img.copy()
img_rb[:,:,1] = 0
plt.imshow(img_rb)

# %%
img_gb = img
img_gb[:,:,2] = 0
plt.imshow(img_gb)

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
img_k = img[20:115,25:120]
plt.imshow(img_k)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
img_r[:,:,1] = 0 #menghapus channel hijau
img_r[:,:,0] = 0 #menghapus channel biru
plt.imshow(img_r[5:30])

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/sample_data/kucing.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi cvhannel BGR -> RGB

# %%
#manual
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(imageWithRectangle, pt1=(250,50),pt2=(450,220), color=(0,255, 255), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(150,150),pt2=(350,250), color=(0,255, 0), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(400,180),pt2=(520,320), color=(255,255, 255), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(270,235),pt2=(375,340), color=(255,0, 0), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(325,300),pt2=(450,450), color=(0,0, 255), thickness = 5)
plt.imshow(imageWithRectangle)

# %%
#secara random

# Membuat salinan gambar untuk ditampilkan
img_display = img3.copy()

# Membuat lima kotak dengan ukuran, posisi, warna, dan ketebalan garis acak
for _ in range(5):
    # Ukuran kotak acak antara 20 dan 100 piksel
    size = random.randint(20, 100)

    # Posisi kotak acak dalam gambar
    x = random.randint(0, img_display.shape[1] - size)
    y = random.randint(0, img_display.shape[0] - size)

    # Warna kotak acak (RGB)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

    # Menggambar kotak pada gambar
    cv.rectangle(img_display, (x, y), (x + size, y + size), color, thickness=5)

    # Mengonversi gambar ke mode warna RGB
    img_display = cv2.cvtColor(img_display, cv2.COLOR_BGR2RGB)

# Menampilkan gambar hasil
cv2_imshow(img_display)
# Out:
# <PIL.Image.Image image mode=RGB size=603x612>

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
#konversi gambar
img_terbalik = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/file image', img5)

#tampilkan plot dengan canvas ynag lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img_terbalik)

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
img7 = cv.imread('/content/sample_data/personal.jpg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img7, pt1=(290,390), pt2=(690,790), color=(255, 0, 30), thickness = 10)
cv.circle(img7, center=(490, 590), radius=180, color=(255, 255, 255), thickness = 15)
ax.imshow(cv.cvtColor(img7, cv.COLOR_BGR2RGB))

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
cv.rectangle(img7, pt1=(5,1180), pt2=(600,1280), color=(255, 0, 30), thickness = 7)
plt.imshow(cv.cvtColor(img7, cv.COLOR_BGR2RGB))

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
font = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(img7,text='Personal Angle',org=(10, 1260),fontFace=font,fontScale=2.7,color=(255,255,255),thickness=2,lineType=cv.LINE_4)
plt.imshow(cv.cvtColor(img7, cv.COLOR_BGR2RGB))

# %% [markdown]
# 10. Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# **TUGAS KELOMPOK**

# %% [markdown]
# Kelompok 3 tutup bagian Gol. Darah dan TTD.

# %%
img_ktp = cv.imread('/content/sample_data/KTP1.jpg')
cv.rectangle(img_ktp, pt1=(300, 130), pt2=(440,150), color=(255, 0, 30), thickness = 2)
cv.circle(img_ktp, center=(525,340), radius=40, color=(255, 255, 255), thickness = 2)
plt.imshow(cv.cvtColor(img_ktp, cv.COLOR_BGR2RGB))
